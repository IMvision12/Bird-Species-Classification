# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input/100-bird-species/285 birds'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

import os
import warnings
warnings.simplefilter('ignore')

import cv2
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Dense,Conv2D,Lambda,Flatten
from tensorflow.keras.layers import Input,MaxPooling2D

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from keras.models import load_model
from keras.preprocessing.image import load_img,img_to_array

# %%
train = '../input/100-bird-species/285 birds/train'
test = '../input/100-bird-species/285 birds/test'
val = '../input/100-bird-species/285 birds/valid'
df = pd.read_csv("../input/100-bird-species/285 birds/Bird Species.csv")

# %%
print("Total Number Of species are: ",len(os.listdir(train)))
# Out:
# Total Number Of species are:  285

# %%
count = 0
for i in os.listdir(train):
    x = train +'/'+ str(i)
    count = count + len(x)
print("Total No of Images",count)
# Out:
# Total No of Images 16002

# %%
for i in os.listdir(train):
    x = train +'/'+ str(i)
    print("Total No of Images in {} are {}".format(str(i),len(x)))
# Out:
# Total No of Images in WATTLED CURASSOW are 58
# Total No of Images in CARMINE BEE-EATER are 59
# Total No of Images in GAMBELS QUAIL are 55
# Total No of Images in UMBRELLA BIRD are 55
# Total No of Images in AMERICAN KESTREL are 58
# Total No of Images in AMERICAN GOLDFINCH are 60
# Total No of Images in BLACK THROATED WARBLER are 64
# Total No of Images in YELLOW CACIQUE are 56
# Total No of Images in STRIPPED SWALLOW are 58
# Total No of Images in VERMILION FLYCATHER are 61
# Total No of Images in CAPE MAY WARBLER are 58
# Total No of Images in GREEN MAGPIE are 54
# Total No of Images in BANDED BROADBILL are 58
# Total No of Images in GREY PLOVER are 53
# Total No of Images in TOUCHAN are 49
# Total No of Images in CALIFORNIA QUAIL are 58
# Total No of Images in BALD IBIS are 51
# Total No of Images in RUBY THROATED HUMMINGBIRD are 67
# Total No of Images in INDIGO BUNTING are 56
# Total No of Images in SORA are 46
# Total No of Images in HOODED MERGANSER are 58
# Total No of Images in CALIFORNIA CONDOR are 59
# Total No of Images in BARN SWALLOW are 54
# Total No of Images in TAIWAN MAGPIE are 55
# Total No of Images in SPLENDID WREN are 55
# Total No of Images in BLACK THROATED BUSHTIT are 64
# Total No of Images in COMMON LOON are 53
# Total No of Images in COMMON POORWILL are 57
# Total No of Images in SUPERB STARLING are 57
# Total No of Images in CUBAN TODY are 52
# Total No of Images in TASMANIAN HEN are 55
# Total No of Images in BLACK SWAN are 52
# Total No of Images in AMERICAN PIPIT are 56
# Total No of Images in LEARS MACAW are 53
# Total No of Images in EASTERN TOWEE are 55
# Total No of Images in GYRFALCON are 51
# Total No of Images in BLACK SKIMMER are 55
# Total No of Images in RED BEARDED BEE EATER are 63
# Total No of Images in NORTHERN BALD IBIS are 60
# Total No of Images in ALBATROSS are 51
# Total No of Images in SPOONBILL are 51
# Total No of Images in MASKED LAPWING are 56
# Total No of Images in MALABAR HORNBILL are 58
# Total No of Images in OCELLATED TURKEY are 58
# Total No of Images in PEREGRINE FALCON are 58
# Total No of Images in ROSY FACED LOVEBIRD are 61
# Total No of Images in GREATOR SAGE GROUSE are 61
# Total No of Images in HORNBILL are 50
# Total No of Images in RUFOUS KINGFISHER are 59
# Total No of Images in JABIRU are 48
# Total No of Images in RED HONEY CREEPER are 59
# Total No of Images in GUINEAFOWL are 52
# Total No of Images in NORTHERN MOCKINGBIRD are 62
# Total No of Images in MALLARD DUCK are 54
# Total No of Images in GILA WOODPECKER are 57
# Total No of Images in BLACK & YELLOW bROADBILL are 66
# Total No of Images in MASKED BOOBY are 54
# Total No of Images in AMERICAN BITTERN are 58
# Total No of Images in CALIFORNIA GULL are 57
# Total No of Images in CASPIAN TERN are 54
# Total No of Images in BARRED PUFFBIRD are 57
# Total No of Images in ELEGANT TROGON are 56
# Total No of Images in SNOWY EGRET are 53
# Total No of Images in GANG GANG COCKATOO are 60
# Total No of Images in RED HEADED WOODPECKER are 63
# Total No of Images in MIKADO  PHEASANT are 58
# Total No of Images in FIRE TAILLED MYZORNIS are 63
# Total No of Images in SWINHOES PHEASANT are 59
# Total No of Images in PARADISE TANAGER are 58
# Total No of Images in OVENBIRD are 50
# Total No of Images in MOURNING DOVE are 55
# Total No of Images in BROWN NOODY are 53
# Total No of Images in DOWNY WOODPECKER are 58
# Total No of Images in EMPEROR PENGUIN are 57
# Total No of Images in WHITE TAILED TROPIC are 61
# Total No of Images in OSPREY are 48
# Total No of Images in HOUSE FINCH are 53
# Total No of Images in AMERICAN COOT are 55
# Total No of Images in GOLDEN PIPIT are 54
# Total No of Images in PUFFIN are 48
# Total No of Images in ARARIPE MANAKIN are 57
# Total No of Images in BLACK-CAPPED CHICKADEE are 64
# Total No of Images in PELICAN are 49
# Total No of Images in KAKAPO are 48
# Total No of Images in RAZORBILL are 51
# Total No of Images in BEARDED REEDLING are 58
# Total No of Images in BELTED KINGFISHER are 59
# Total No of Images in KILLDEAR are 50
# Total No of Images in HELMET VANGA are 54
# Total No of Images in BAR-TAILED GODWIT are 59
# Total No of Images in YELLOW BELLIED FLOWERPECKER are 69
# Total No of Images in RED TAILED THRUSH are 59
# Total No of Images in STEAMER DUCK are 54
# Total No of Images in RED BELLIED PITTA are 59
# Total No of Images in GRAY CATBIRD are 54
# Total No of Images in GUINEA TURACO are 55
# Total No of Images in RED WISKERED BULBUL are 61
# Total No of Images in PHILIPPINE EAGLE are 58
# Total No of Images in ANHINGA are 49
# Total No of Images in SPOON BILED SANDPIPER are 63
# Total No of Images in VULTURINE GUINEAFOWL are 62
# Total No of Images in ENGGANO MYNA are 54
# Total No of Images in BIRD OF PARADISE are 58
# Total No of Images in LILAC ROLLER are 54
# Total No of Images in BANANAQUIT are 52
# Total No of Images in CHUKAR PARTRIDGE are 58
# Total No of Images in CACTUS WREN are 53
# Total No of Images in BALD EAGLE are 52
# Total No of Images in NICOBAR PIGEON are 56
# Total No of Images in KIWI are 46
# Total No of Images in AFRICAN FIREFINCH are 59
# Total No of Images in CRESTED NUTHATCH are 58
# Total No of Images in GOLD WING WARBLER are 59
# Total No of Images in COCKATOO are 50
# Total No of Images in EMU are 45
# Total No of Images in HARPY EAGLE are 53
# Total No of Images in CUBAN TROGON are 54
# Total No of Images in BLUE HERON are 52
# Total No of Images in EURASIAN MAGPIE are 57
# Total No of Images in RED WINGED BLACKBIRD are 62
# Total No of Images in BORNEAN BRISTLEHEAD are 61
# Total No of Images in STRAWBERRY FINCH are 58
# Total No of Images in ORANGE BRESTED BUNTING are 64
# Total No of Images in PAINTED BUNTIG are 56
# Total No of Images in SCARLET TANAGER are 57
# Total No of Images in MAGPIE GOOSE are 54
# Total No of Images in WHITE THROATED BEE EATER are 66
# Total No of Images in BLACK FRANCOLIN are 57
# Total No of Images in COLLARED ARACARI are 58
# Total No of Images in CRESTED AUKLET are 56
# Total No of Images in GLOSSY IBIS are 53
# Total No of Images in NORTHERN CARDINAL are 59
# Total No of Images in KAGU are 46
# Total No of Images in PURPLE FINCH are 54
# Total No of Images in HORNED SUNGEM are 55
# Total No of Images in MYNA are 46
# Total No of Images in COMMON HOUSE MARTIN are 61
# Total No of Images in EURASIAN GOLDEN ORIOLE are 64
# Total No of Images in NORTHERN SHOVELER are 59
# Total No of Images in PARAKETT  AKULET are 58
# Total No of Images in ANTBIRD are 49
# Total No of Images in ALEXANDRINE PARAKEET are 62
# Total No of Images in CEDAR WAXWING are 55
# Total No of Images in KING VULTURE are 54
# Total No of Images in SAND MARTIN are 53
# Total No of Images in SMITHS LONGSPUR are 57
# Total No of Images in PYGMY KINGFISHER are 58
# Total No of Images in GOULDIAN FINCH are 56
# Total No of Images in CROW are 46
# Total No of Images in BROWN CREPPER are 55
# Total No of Images in NOISY FRIARBIRD are 57
# Total No of Images in WHITE CHEEKED TURACO are 62
# Total No of Images in BARN OWL are 50
# Total No of Images in OSTRICH are 49
# Total No of Images in ROUGH LEG BUZZARD are 59
# Total No of Images in RAINBOW LORIKEET are 58
# Total No of Images in PARUS MAJOR are 53
# Total No of Images in LONG-EARED OWL are 56
# Total No of Images in MARABOU STORK are 55
# Total No of Images in BLACK TAIL CRAKE are 58
# Total No of Images in INCA TERN are 51
# Total No of Images in EASTERN BLUEBIRD are 58
# Total No of Images in PALILA are 48
# Total No of Images in HOOPOES are 49
# Total No of Images in OKINAWA RAIL are 54
# Total No of Images in CHIPPING SPARROW are 58
# Total No of Images in ANNAS HUMMINGBIRD are 59
# Total No of Images in CINNAMON TEAL are 55
# Total No of Images in ROBIN are 47
# Total No of Images in VENEZUELIAN TROUPIAL are 62
# Total No of Images in MALEO are 47
# Total No of Images in WHITE NECKED RAVEN are 60
# Total No of Images in PINK ROBIN are 52
# Total No of Images in BOBOLINK are 50
# Total No of Images in MANDRIN DUCK are 54
# Total No of Images in RED BROWED FINCH are 58
# Total No of Images in NORTHERN PARULA are 57
# Total No of Images in AMERICAN AVOCET are 57
# Total No of Images in EVENING GROSBEAK are 58
# Total No of Images in RED HEADED DUCK are 57
# Total No of Images in TREE SWALLOW are 54
# Total No of Images in COMMON GRACKLE are 56
# Total No of Images in SCARLET MACAW are 55
# Total No of Images in HORNED GUAN are 53
# Total No of Images in CAPUCHINBIRD are 54
# Total No of Images in CROWNED PIGEON are 56
# Total No of Images in WILD TURKEY are 53
# Total No of Images in VIOLET GREEN SWALLOW are 62
# Total No of Images in GREEN JAY are 51
# Total No of Images in RUFUOS MOTMOT are 55
# Total No of Images in NORTHERN JACANA are 57
# Total No of Images in ROADRUNNER are 52
# Total No of Images in BLUE GROUSE are 53
# Total No of Images in TEAL DUCK are 51
# Total No of Images in DARK EYED JUNCO are 57
# Total No of Images in CLARKS NUTCRACKER are 59
# Total No of Images in GILDED FLICKER are 56
# Total No of Images in FLAMINGO are 50
# Total No of Images in BALI STARLING are 55
# Total No of Images in ROCK DOVE are 51
# Total No of Images in CHARA DE COLLAR are 57
# Total No of Images in TOWNSENDS WARBLER are 59
# Total No of Images in D-ARNAUDS BARBET are 58
# Total No of Images in OYSTER CATCHER are 56
# Total No of Images in VARIED THRUSH are 55
# Total No of Images in SRI LANKA BLUE MAGPIE are 63
# Total No of Images in LARK BUNTING are 54
# Total No of Images in DOUBLE BARRED FINCH are 61
# Total No of Images in FAIRY BLUEBIRD are 56
# Total No of Images in HOUSE SPARROW are 55
# Total No of Images in CRESTED CARACARA are 58
# Total No of Images in NORTHERN GANNET are 57
# Total No of Images in SCARLET IBIS are 54
# Total No of Images in MALACHITE KINGFISHER are 62
# Total No of Images in INDIAN PITTA are 54
# Total No of Images in EASTERN MEADOWLARK are 60
# Total No of Images in REGENT BOWERBIRD are 58
# Total No of Images in WILSONS BIRD OF PARADISE are 66
# Total No of Images in SHORT BILLED DOWITCHER are 64
# Total No of Images in BLACK-THROATED SPARROW are 64
# Total No of Images in NORTHERN FLICKER are 58
# Total No of Images in PURPLE GALLINULE are 58
# Total No of Images in CANARY are 48
# Total No of Images in TAKAHE are 48
# Total No of Images in COUCHS KINGBIRD are 57
# Total No of Images in FLAME TANAGER are 55
# Total No of Images in CURL CRESTED ARACURI are 62
# Total No of Images in RED FACED CORMORANT are 61
# Total No of Images in ROYAL FLYCATCHER are 58
# Total No of Images in BULWERS PHEASANT are 58
# Total No of Images in HORNED LARK are 53
# Total No of Images in COCK OF THE  ROCK are 59
# Total No of Images in TIT MOUSE are 51
# Total No of Images in GRAY PARTRIDGE are 56
# Total No of Images in WOOD DUCK are 51
# Total No of Images in RED FACED WARBLER are 59
# Total No of Images in HIMALAYAN MONAL are 57
# Total No of Images in QUETZAL are 49
# Total No of Images in NORTHERN GOSHAWK are 58
# Total No of Images in GOLDEN CHLOROPHONIA are 61
# Total No of Images in PURPLE SWAMPHEN are 57
# Total No of Images in COMMON FIRECREST are 58
# Total No of Images in TURQUOISE MOTMOT are 58
# Total No of Images in CASSOWARY are 51
# Total No of Images in INDIAN BUSTARD are 56
# Total No of Images in KOOKABURRA are 52
# Total No of Images in RING-NECKED PHEASANT are 62
# Total No of Images in EASTERN ROSELLA are 57
# Total No of Images in PURPLE MARTIN are 55
# Total No of Images in VICTORIA CROWNED PIGEON are 65
# Total No of Images in SHOEBILL are 50
# Total No of Images in SNOWY OWL are 51
# Total No of Images in AFRICAN CROWNED CRANE are 63
# Total No of Images in GREAT POTOO are 53
# Total No of Images in STORK BILLED KINGFISHER are 65
# Total No of Images in GOLDEN PHEASANT are 57
# Total No of Images in ASIAN CRESTED IBIS are 60
# Total No of Images in BLACK-NECKED GREBE are 60
# Total No of Images in BALTIMORE ORIOLE are 58
# Total No of Images in COMMON STARLING are 57
# Total No of Images in BLACKBURNIAM WARBLER are 62
# Total No of Images in WHIMBREL are 50
# Total No of Images in YELLOW HEADED BLACKBIRD are 65
# Total No of Images in SPANGLED COTINGA are 58
# Total No of Images in HAWAIIAN GOOSE are 56
# Total No of Images in PEACOCK are 49
# Total No of Images in BEARDED BARBET are 56
# Total No of Images in TURKEY VULTURE are 56
# Total No of Images in BLACK VULTURE are 55
# Total No of Images in BROWN THRASHER are 56
# Total No of Images in GOLDEN CHEEKED WARBLER are 64
# Total No of Images in DOUBLE BRESTED CORMARANT are 66
# Total No of Images in JAVA SPARROW are 54
# Total No of Images in BAY-BREASTED WARBLER are 62
# Total No of Images in HOATZIN are 49
# Total No of Images in GO AWAY BIRD are 54
# Total No of Images in ELLIOTS  PHEASANT are 59
# Total No of Images in IMPERIAL SHAQ are 55
# Total No of Images in FRIGATE are 49
# Total No of Images in TRUMPTER SWAN are 55
# Total No of Images in SAMATRAN THRUSH are 57
# Total No of Images in BORNEAN LEAFBIRD are 58
# Total No of Images in AMERICAN REDSTART are 59
# Total No of Images in NORTHERN RED BISHOP are 61
# Total No of Images in GOLDEN EAGLE are 54

# %%
df.head()
# Out:
#                              filepaths                 labels data set
# 0  train/AFRICAN CROWNED CRANE/001.jpg  AFRICAN CROWNED CRANE    train
# 1  train/AFRICAN CROWNED CRANE/002.jpg  AFRICAN CROWNED CRANE    train
# 2  train/AFRICAN CROWNED CRANE/003.jpg  AFRICAN CROWNED CRANE    train
# 3  train/AFRICAN CROWNED CRANE/004.jpg  AFRICAN CROWNED CRANE    train
# 4  train/AFRICAN CROWNED CRANE/005.jpg  AFRICAN CROWNED CRANE    train

# %%
df = df.sample(frac=1)
df_for_img = df.head()

# %%
paths = []
for i in range(5):
    x = df_for_img.iloc[i][0].split('\\')
    y = '/'.join(x)
    paths.append(y)
df_path = pd.DataFrame(paths)
df_path.columns=['paths']
df_path
# Out:
#                           paths
# 0   train/HOUSE SPARROW/006.jpg
# 1    train/MASKED BOOBY/019.jpg
# 2          train/TAKAHE/082.jpg
# 3  train/OYSTER CATCHER/170.jpg
# 4   test/PHILIPPINE EAGLE/5.jpg

# %%
plt.figure(figsize=(16,11))
folder = '../input/100-bird-species/285 birds/'    
for i in range(5):
    plt.subplot(1,5,i+1)
    x = folder + df_path.iloc[i][0]
    image = plt.imread(x)
    plt.imshow(image)
    plt.title(df_for_img.iloc[i][1])

# %%
image_size = [224,224]
vgg = VGG16(input_shape = image_size + [3],
            weights = 'imagenet',include_top=False)

for layer in vgg.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
folder = len(os.listdir(train))
folder
# Out:
# 285

# %%
x = Flatten()(vgg.output)
classification = Dense(int(folder),activation='softmax')(x)

model = Model(inputs = vgg.input,outputs = classification)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 285)               7150365
# =================================================================
# Total params: 21,865,053
# Trainable params: 7,150,365
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])

# %%
train_generator = ImageDataGenerator(rescale = 1./255,
                                    shear_range = 0.2,
                                    zoom_range = 0.2,
                                    horizontal_flip = True,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2)

test_generator = ImageDataGenerator(rescale=1./255)

# %%
train_set = train_generator.flow_from_directory(train,
                                               target_size=(224,224),
                                               batch_size=32,
                                               class_mode = 'categorical')

valid_set = train_generator.flow_from_directory(val,
                                               target_size=(224,224),
                                               batch_size=32,
                                               class_mode = 'categorical')

test_set = test_generator.flow_from_directory(test,
                                               target_size=(224,224),
                                               batch_size=32,
                                               class_mode = 'categorical')
# Out:
# Found 40930 images belonging to 285 classes.
# Found 1425 images belonging to 285 classes.
# Found 1425 images belonging to 285 classes.

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
# !nvidia-smi
# Out:
# Sat Aug 28 05:29:27 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    36W / 250W |  15327MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
history = model.fit(train_set,validation_data = valid_set,
                    epochs=50,steps_per_epoch=len(train_set),
                    validation_steps=len(test_set))
# Out:
# Epoch 1/50
# 1280/1280 [==============================] - 743s 573ms/step - loss: 6.6207 - accuracy: 0.1632 - val_loss: 3.9086 - val_accuracy: 0.4239
# Epoch 2/50
# 1280/1280 [==============================] - 544s 425ms/step - loss: 4.2862 - accuracy: 0.4153 - val_loss: 3.7487 - val_accuracy: 0.4989
# Epoch 3/50
# 1280/1280 [==============================] - 557s 435ms/step - loss: 4.0084 - accuracy: 0.4830 - val_loss: 3.5948 - val_accuracy: 0.5460
# Epoch 4/50
# 1280/1280 [==============================] - 569s 444ms/step - loss: 3.6385 - accuracy: 0.5447 - val_loss: 3.4208 - val_accuracy: 0.5698
# Epoch 5/50
# 1280/1280 [==============================] - 599s 468ms/step - loss: 3.4765 - accuracy: 0.5734 - val_loss: 3.4057 - val_accuracy: 0.5951
# Epoch 6/50
# 1280/1280 [==============================] - 607s 474ms/step - loss: 3.3349 - accuracy: 0.5969 - val_loss: 3.8540 - val_accuracy: 0.5909
# Epoch 7/50
# 1280/1280 [==============================] - 630s 492ms/step - loss: 3.2830 - accuracy: 0.6083 - val_loss: 3.1953 - val_accuracy: 0.6484
# Epoch 8/50
# 1280/1280 [==============================] - 644s 503ms/step - loss: 3.1186 - accuracy: 0.6318 - val_loss: 3.4230 - val_accuracy: 0.6267
# Epoch 9/50
# 1280/1280 [==============================] - 648s 506ms/step - loss: 3.0562 - accuracy: 0.6481 - val_loss: 3.0601 - val_accuracy: 0.6625
# Epoch 10/50
# 1280/1280 [==============================] - 628s 491ms/step - loss: 2.9924 - accuracy: 0.6612 - val_loss: 3.5837 - val_accuracy: 0.6533
# Epoch 11/50
# 1280/1280 [==============================] - 631s 493ms/step - loss: 2.9868 - accuracy: 0.6691 - val_loss: 3.4539 - val_accuracy: 0.6632
# Epoch 12/50
# 1280/1280 [==============================] - 627s 490ms/step - loss: 2.8241 - accuracy: 0.6812 - val_loss: 3.6208 - val_accuracy: 0.6547
# Epoch 13/50
# 1280/1280 [==============================] - 617s 482ms/step - loss: 2.9324 - accuracy: 0.6820 - val_loss: 3.4869 - val_accuracy: 0.6653
# Epoch 14/50
# 1280/1280 [==============================] - 624s 488ms/step - loss: 2.7131 - accuracy: 0.6933 - val_loss: 3.5363 - val_accuracy: 0.6744
# Epoch 15/50
# 1280/1280 [==============================] - 633s 495ms/step - loss: 2.6889 - accuracy: 0.7057 - val_loss: 3.5294 - val_accuracy: 0.6709
# Epoch 16/50
# 1280/1280 [==============================] - 633s 495ms/step - loss: 2.6987 - accuracy: 0.7100 - val_loss: 3.6284 - val_accuracy: 0.6856
# Epoch 17/50
# 1280/1280 [==============================] - 639s 499ms/step - loss: 2.5418 - accuracy: 0.7233 - val_loss: 3.3511 - val_accuracy: 0.7032
# Epoch 18/50
# 1280/1280 [==============================] - 638s 499ms/step - loss: 2.5590 - accuracy: 0.7238 - val_loss: 3.3365 - val_accuracy: 0.7053
# Epoch 19/50
# 1280/1280 [==============================] - 626s 489ms/step - loss: 2.5007 - accuracy: 0.7362 - val_loss: 3.5459 - val_accuracy: 0.6947
# Epoch 20/50
# 1280/1280 [==============================] - 652s 510ms/step - loss: 2.4617 - accuracy: 0.7373 - val_loss: 3.5210 - val_accuracy: 0.7186
# Epoch 21/50
# 1280/1280 [==============================] - 618s 483ms/step - loss: 2.3950 - accuracy: 0.7449 - val_loss: 3.5921 - val_accuracy: 0.7067
# Epoch 22/50
# 1280/1280 [==============================] - 616s 481ms/step - loss: 2.4431 - accuracy: 0.7522 - val_loss: 3.5495 - val_accuracy: 0.7053
# Epoch 23/50
# 1280/1280 [==============================] - 599s 468ms/step - loss: 2.4612 - accuracy: 0.7473 - val_loss: 3.4847 - val_accuracy: 0.7004
# Epoch 24/50
# 1280/1280 [==============================] - 587s 458ms/step - loss: 2.4060 - accuracy: 0.7507 - val_loss: 3.6109 - val_accuracy: 0.7116
# Epoch 25/50
# 1280/1280 [==============================] - 580s 453ms/step - loss: 2.3150 - accuracy: 0.7580 - val_loss: 3.7333 - val_accuracy: 0.7095
# Epoch 26/50
# 1280/1280 [==============================] - 587s 459ms/step - loss: 2.2676 - accuracy: 0.7666 - val_loss: 3.6615 - val_accuracy: 0.7193
# Epoch 27/50
# 1280/1280 [==============================] - 587s 459ms/step - loss: 2.2964 - accuracy: 0.7664 - val_loss: 3.6840 - val_accuracy: 0.7186
# Epoch 28/50
# 1280/1280 [==============================] - 582s 455ms/step - loss: 2.2068 - accuracy: 0.7715 - val_loss: 3.8928 - val_accuracy: 0.7193
# Epoch 29/50
# 1280/1280 [==============================] - 601s 470ms/step - loss: 2.1873 - accuracy: 0.7784 - val_loss: 3.7603 - val_accuracy: 0.7270
# Epoch 30/50
# 1280/1280 [==============================] - 587s 459ms/step - loss: 2.1877 - accuracy: 0.7803 - val_loss: 3.7763 - val_accuracy: 0.7235
# Epoch 31/50
# 1280/1280 [==============================] - 593s 463ms/step - loss: 2.1361 - accuracy: 0.7811 - val_loss: 3.8005 - val_accuracy: 0.7088
# Epoch 32/50
# 1280/1280 [==============================] - 596s 466ms/step - loss: 2.1816 - accuracy: 0.7825 - val_loss: 3.5376 - val_accuracy: 0.7439
# Epoch 33/50
# 1280/1280 [==============================] - 594s 464ms/step - loss: 2.0742 - accuracy: 0.7916 - val_loss: 3.7274 - val_accuracy: 0.7361
# Epoch 34/50
# 1280/1280 [==============================] - 590s 461ms/step - loss: 2.1158 - accuracy: 0.7919 - val_loss: 3.5680 - val_accuracy: 0.7277
# Epoch 35/50
# 1280/1280 [==============================] - 584s 456ms/step - loss: 2.0517 - accuracy: 0.7945 - val_loss: 3.7200 - val_accuracy: 0.7368
# Epoch 36/50
# 1280/1280 [==============================] - 590s 461ms/step - loss: 2.0748 - accuracy: 0.7951 - val_loss: 3.4894 - val_accuracy: 0.7354
# Epoch 37/50
# 1280/1280 [==============================] - 599s 468ms/step - loss: 2.0986 - accuracy: 0.7962 - val_loss: 3.2611 - val_accuracy: 0.7418
# Epoch 38/50
# 1280/1280 [==============================] - 591s 462ms/step - loss: 2.0429 - accuracy: 0.8016 - val_loss: 3.6833 - val_accuracy: 0.7347
# Epoch 39/50
# 1280/1280 [==============================] - 569s 444ms/step - loss: 2.0161 - accuracy: 0.8015 - val_loss: 3.5192 - val_accuracy: 0.7453
# Epoch 40/50
# 1280/1280 [==============================] - 606s 473ms/step - loss: 1.9767 - accuracy: 0.8073 - val_loss: 4.0126 - val_accuracy: 0.7354
# Epoch 41/50
# 1280/1280 [==============================] - 592s 463ms/step - loss: 1.9237 - accuracy: 0.8098 - val_loss: 3.6158 - val_accuracy: 0.7439
# Epoch 42/50
# 1280/1280 [==============================] - 598s 467ms/step - loss: 1.9968 - accuracy: 0.8068 - val_loss: 3.9113 - val_accuracy: 0.7312
# Epoch 43/50
# 1280/1280 [==============================] - 602s 470ms/step - loss: 1.8887 - accuracy: 0.8136 - val_loss: 3.9134 - val_accuracy: 0.7242
# Epoch 44/50
# 1280/1280 [==============================] - 632s 494ms/step - loss: 1.9511 - accuracy: 0.8150 - val_loss: 4.2959 - val_accuracy: 0.7270
# Epoch 45/50
# 1280/1280 [==============================] - 619s 484ms/step - loss: 1.9603 - accuracy: 0.8094 - val_loss: 3.7325 - val_accuracy: 0.7502
# Epoch 46/50
# 1280/1280 [==============================] - 617s 482ms/step - loss: 1.8713 - accuracy: 0.8179 - val_loss: 3.7614 - val_accuracy: 0.7439
# Epoch 47/50
# 1280/1280 [==============================] - 592s 463ms/step - loss: 1.9305 - accuracy: 0.8130 - val_loss: 3.6905 - val_accuracy: 0.7453
# Epoch 48/50
# 1280/1280 [==============================] - 614s 480ms/step - loss: 1.9281 - accuracy: 0.8206 - val_loss: 4.0382 - val_accuracy: 0.7277
# Epoch 49/50
# 1280/1280 [==============================] - 624s 487ms/step - loss: 1.8197 - accuracy: 0.8295 - val_loss: 3.9788 - val_accuracy: 0.7389
# Epoch 50/50
# 1280/1280 [==============================] - 615s 481ms/step - loss: 1.8652 - accuracy: 0.8241 - val_loss: 3.9628 - val_accuracy: 0.7411

# %%
#Training
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(['Train','Test'],loc='upper left')
plt.show()
#Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(['Train','Test'],loc='upper left')
plt.show()

# %% [markdown]
# # Model Saving

# %%
model.save("birds_classification_vgg.h5")
loaded_model = load_model('birds_classification_vgg.h5', compile = False)

# %%
model.save("./saved_model/")

# %% [markdown]
# ## Converting to tflite
# without quantization

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("./saved_model")
tflite_model = converter.convert()

# %%
len(tflite_model)
# Out:
# 87466720

# %% [markdown]
# ## With quantization

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("./saved_model")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()

# %%
len(tflite_quant_model)
# Out:
# 21970624

# %%
with open("tflite_model.tflite", "wb") as f:
    f.write(tflite_model)

# %%
with open("tflite_quant_model.tflite", "wb") as f:
    f.write(tflite_quant_model)

# %% [markdown]
# ## Testing

# %%
labels = train_set.class_indices
labels_reverse = {k:v for v,k in labels.items()}
labels_reverse
# Out:
# {0: 'AFRICAN CROWNED CRANE',
#  1: 'AFRICAN FIREFINCH',
#  2: 'ALBATROSS',
#  3: 'ALEXANDRINE PARAKEET',
#  4: 'AMERICAN AVOCET',
#  5: 'AMERICAN BITTERN',
#  6: 'AMERICAN COOT',
#  7: 'AMERICAN GOLDFINCH',
#  8: 'AMERICAN KESTREL',
#  9: 'AMERICAN PIPIT',
#  10: 'AMERICAN REDSTART',
#  11: 'ANHINGA',
#  12: 'ANNAS HUMMINGBIRD',
#  13: 'ANTBIRD',
#  14: 'ARARIPE MANAKIN',
#  15: 'ASIAN CRESTED IBIS',
#  16: 'BALD EAGLE',
#  17: 'BALD IBIS',
#  18: 'BALI STARLING',
#  19: 'BALTIMORE ORIOLE',
#  20: 'BANANAQUIT',
#  21: 'BANDED BROADBILL',
#  22: 'BAR-TAILED GODWIT',
#  23: 'BARN OWL',
#  24: 'BARN SWALLOW',
#  25: 'BARRED PUFFBIRD',
#  26: 'BAY-BREASTED WARBLER',
#  27: 'BEARDED BARBET',
#  28: 'BEARDED REEDLING',
#  29: 'BELTED KINGFISHER',
#  30: 'BIRD OF PARADISE',
#  31: 'BLACK & YELLOW bROADBILL',
#  32: 'BLACK FRANCOLIN',
#  33: 'BLACK SKIMMER',
#  34: 'BLACK SWAN',
#  35: 'BLACK TAIL CRAKE',
#  36: 'BLACK THROATED BUSHTIT',
#  37: 'BLACK THROATED WARBLER',
#  38: 'BLACK VULTURE',
#  39: 'BLACK-CAPPED CHICKADEE',
#  40: 'BLACK-NECKED GREBE',
#  41: 'BLACK-THROATED SPARROW',
#  42: 'BLACKBURNIAM WARBLER',
#  43: 'BLUE GROUSE',
#  44: 'BLUE HERON',
#  45: 'BOBOLINK',
#  46: 'BORNEAN BRISTLEHEAD',
#  47: 'BORNEAN LEAFBIRD',
#  48: 'BROWN CREPPER',
#  49: 'BROWN NOODY',
#  50: 'BROWN THRASHER',
#  51: 'BULWERS PHEASANT',
#  52: 'CACTUS WREN',
#  53: 'CALIFORNIA CONDOR',
#  54: 'CALIFORNIA GULL',
#  55: 'CALIFORNIA QUAIL',
#  56: 'CANARY',
#  57: 'CAPE MAY WARBLER',
#  58: 'CAPUCHINBIRD',
#  59: 'CARMINE BEE-EATER',
#  60: 'CASPIAN TERN',
#  61: 'CASSOWARY',
#  62: 'CEDAR WAXWING',
#  63: 'CHARA DE COLLAR',
#  64: 'CHIPPING SPARROW',
#  65: 'CHUKAR PARTRIDGE',
#  66: 'CINNAMON TEAL',
#  67: 'CLARKS NUTCRACKER',
#  68: 'COCK OF THE  ROCK',
#  69: 'COCKATOO',
#  70: 'COLLARED ARACARI',
#  71: 'COMMON FIRECREST',
#  72: 'COMMON GRACKLE',
#  73: 'COMMON HOUSE MARTIN',
#  74: 'COMMON LOON',
#  75: 'COMMON POORWILL',
#  76: 'COMMON STARLING',
#  77: 'COUCHS KINGBIRD',
#  78: 'CRESTED AUKLET',
#  79: 'CRESTED CARACARA',
#  80: 'CRESTED NUTHATCH',
#  81: 'CROW',
#  82: 'CROWNED PIGEON',
#  83: 'CUBAN TODY',
#  84: 'CUBAN TROGON',
#  85: 'CURL CRESTED ARACURI',
#  86: 'D-ARNAUDS BARBET',
#  87: 'DARK EYED JUNCO',
#  88: 'DOUBLE BARRED FINCH',
#  89: 'DOUBLE BRESTED CORMARANT',
#  90: 'DOWNY WOODPECKER',
#  91: 'EASTERN BLUEBIRD',
#  92: 'EASTERN MEADOWLARK',
#  93: 'EASTERN ROSELLA',
#  94: 'EASTERN TOWEE',
#  95: 'ELEGANT TROGON',
#  96: 'ELLIOTS  PHEASANT',
#  97: 'EMPEROR PENGUIN',
#  98: 'EMU',
#  99: 'ENGGANO MYNA',
#  100: 'EURASIAN GOLDEN ORIOLE',
#  101: 'EURASIAN MAGPIE',
#  102: 'EVENING GROSBEAK',
#  103: 'FAIRY BLUEBIRD',
#  104: 'FIRE TAILLED MYZORNIS',
#  105: 'FLAME TANAGER',
#  106: 'FLAMINGO',
#  107: 'FRIGATE',
#  108: 'GAMBELS QUAIL',
#  109: 'GANG GANG COCKATOO',
#  110: 'GILA WOODPECKER',
#  111: 'GILDED FLICKER',
#  112: 'GLOSSY IBIS',
#  113: 'GO AWAY BIRD',
#  114: 'GOLD WING WARBLER',
#  115: 'GOLDEN CHEEKED WARBLER',
#  116: 'GOLDEN CHLOROPHONIA',
#  117: 'GOLDEN EAGLE',
#  118: 'GOLDEN PHEASANT',
#  119: 'GOLDEN PIPIT',
#  120: 'GOULDIAN FINCH',
#  121: 'GRAY CATBIRD',
#  122: 'GRAY PARTRIDGE',
#  123: 'GREAT POTOO',
#  124: 'GREATOR SAGE GROUSE',
#  125: 'GREEN JAY',
#  126: 'GREEN MAGPIE',
#  127: 'GREY PLOVER',
#  128: 'GUINEA TURACO',
#  129: 'GUINEAFOWL',
#  130: 'GYRFALCON',
#  131: 'HARPY EAGLE',
#  132: 'HAWAIIAN GOOSE',
#  133: 'HELMET VANGA',
#  134: 'HIMALAYAN MONAL',
#  135: 'HOATZIN',
#  136: 'HOODED MERGANSER',
#  137: 'HOOPOES',
#  138: 'HORNBILL',
#  139: 'HORNED GUAN',
#  140: 'HORNED LARK',
#  141: 'HORNED SUNGEM',
#  142: 'HOUSE FINCH',
#  143: 'HOUSE SPARROW',
#  144: 'IMPERIAL SHAQ',
#  145: 'INCA TERN',
#  146: 'INDIAN BUSTARD',
#  147: 'INDIAN PITTA',
#  148: 'INDIGO BUNTING',
#  149: 'JABIRU',
#  150: 'JAVA SPARROW',
#  151: 'KAGU',
#  152: 'KAKAPO',
#  153: 'KILLDEAR',
#  154: 'KING VULTURE',
#  155: 'KIWI',
#  156: 'KOOKABURRA',
#  157: 'LARK BUNTING',
#  158: 'LEARS MACAW',
#  159: 'LILAC ROLLER',
#  160: 'LONG-EARED OWL',
#  161: 'MAGPIE GOOSE',
#  162: 'MALABAR HORNBILL',
#  163: 'MALACHITE KINGFISHER',
#  164: 'MALEO',
#  165: 'MALLARD DUCK',
#  166: 'MANDRIN DUCK',
#  167: 'MARABOU STORK',
#  168: 'MASKED BOOBY',
#  169: 'MASKED LAPWING',
#  170: 'MIKADO  PHEASANT',
#  171: 'MOURNING DOVE',
#  172: 'MYNA',
#  173: 'NICOBAR PIGEON',
#  174: 'NOISY FRIARBIRD',
#  175: 'NORTHERN BALD IBIS',
#  176: 'NORTHERN CARDINAL',
#  177: 'NORTHERN FLICKER',
#  178: 'NORTHERN GANNET',
#  179: 'NORTHERN GOSHAWK',
#  180: 'NORTHERN JACANA',
#  181: 'NORTHERN MOCKINGBIRD',
#  182: 'NORTHERN PARULA',
#  183: 'NORTHERN RED BISHOP',
#  184: 'NORTHERN SHOVELER',
#  185: 'OCELLATED TURKEY',
#  186: 'OKINAWA RAIL',
#  187: 'ORANGE BRESTED BUNTING',
#  188: 'OSPREY',
#  189: 'OSTRICH',
#  190: 'OVENBIRD',
#  191: 'OYSTER CATCHER',
#  192: 'PAINTED BUNTIG',
#  193: 'PALILA',
#  194: 'PARADISE TANAGER',
#  195: 'PARAKETT  AKULET',
#  196: 'PARUS MAJOR',
#  197: 'PEACOCK',
#  198: 'PELICAN',
#  199: 'PEREGRINE FALCON',
#  200: 'PHILIPPINE EAGLE',
#  201: 'PINK ROBIN',
#  202: 'PUFFIN',
#  203: 'PURPLE FINCH',
#  204: 'PURPLE GALLINULE',
#  205: 'PURPLE MARTIN',
#  206: 'PURPLE SWAMPHEN',
#  207: 'PYGMY KINGFISHER',
#  208: 'QUETZAL',
#  209: 'RAINBOW LORIKEET',
#  210: 'RAZORBILL',
#  211: 'RED BEARDED BEE EATER',
#  212: 'RED BELLIED PITTA',
#  213: 'RED BROWED FINCH',
#  214: 'RED FACED CORMORANT',
#  215: 'RED FACED WARBLER',
#  216: 'RED HEADED DUCK',
#  217: 'RED HEADED WOODPECKER',
#  218: 'RED HONEY CREEPER',
#  219: 'RED TAILED THRUSH',
#  220: 'RED WINGED BLACKBIRD',
#  221: 'RED WISKERED BULBUL',
#  222: 'REGENT BOWERBIRD',
#  223: 'RING-NECKED PHEASANT',
#  224: 'ROADRUNNER',
#  225: 'ROBIN',
#  226: 'ROCK DOVE',
#  227: 'ROSY FACED LOVEBIRD',
#  228: 'ROUGH LEG BUZZARD',
#  229: 'ROYAL FLYCATCHER',
#  230: 'RUBY THROATED HUMMINGBIRD',
#  231: 'RUFOUS KINGFISHER',
#  232: 'RUFUOS MOTMOT',
#  233: 'SAMATRAN THRUSH',
#  234: 'SAND MARTIN',
#  235: 'SCARLET IBIS',
#  236: 'SCARLET MACAW',
#  237: 'SCARLET TANAGER',
#  238: 'SHOEBILL',
#  239: 'SHORT BILLED DOWITCHER',
#  240: 'SMITHS LONGSPUR',
#  241: 'SNOWY EGRET',
#  242: 'SNOWY OWL',
#  243: 'SORA',
#  244: 'SPANGLED COTINGA',
#  245: 'SPLENDID WREN',
#  246: 'SPOON BILED SANDPIPER',
#  247: 'SPOONBILL',
#  248: 'SRI LANKA BLUE MAGPIE',
#  249: 'STEAMER DUCK',
#  250: 'STORK BILLED KINGFISHER',
#  251: 'STRAWBERRY FINCH',
#  252: 'STRIPPED SWALLOW',
#  253: 'SUPERB STARLING',
#  254: 'SWINHOES PHEASANT',
#  255: 'TAIWAN MAGPIE',
#  256: 'TAKAHE',
#  257: 'TASMANIAN HEN',
#  258: 'TEAL DUCK',
#  259: 'TIT MOUSE',
#  260: 'TOUCHAN',
#  261: 'TOWNSENDS WARBLER',
#  262: 'TREE SWALLOW',
#  263: 'TRUMPTER SWAN',
#  264: 'TURKEY VULTURE',
#  265: 'TURQUOISE MOTMOT',
#  266: 'UMBRELLA BIRD',
#  267: 'VARIED THRUSH',
#  268: 'VENEZUELIAN TROUPIAL',
#  269: 'VERMILION FLYCATHER',
#  270: 'VICTORIA CROWNED PIGEON',
#  271: 'VIOLET GREEN SWALLOW',
#  272: 'VULTURINE GUINEAFOWL',
#  273: 'WATTLED CURASSOW',
#  274: 'WHIMBREL',
#  275: 'WHITE CHEEKED TURACO',
#  276: 'WHITE NECKED RAVEN',
#  277: 'WHITE TAILED TROPIC',
#  278: 'WHITE THROATED BEE EATER',
#  279: 'WILD TURKEY',
#  280: 'WILSONS BIRD OF PARADISE',
#  281: 'WOOD DUCK',
#  282: 'YELLOW BELLIED FLOWERPECKER',
#  283: 'YELLOW CACIQUE',
#  284: 'YELLOW HEADED BLACKBIRD'}

# %%
def output(location):
    img = load_img(location, target_size = (224, 224, 3))
    img = img_to_array(img)
    img = img / 255
    img = np.expand_dims(img, [0])
    answer = loaded_model.predict(img)
    y_class = answer.argmax(axis = -1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels_reverse[y]
    return res

# %%
img = '../input/100-bird-species/birds/valid/AMERICAN BITTERN/1.jpg'
pic = load_img(img, target_size = (224, 224, 3))
plt.imshow(pic)
output(img)
# Out:
# 'AMERICAN BITTERN'

# %%
img = '../input/100-bird-species/birds/valid/AMERICAN COOT/1.jpg'
pic = load_img(img, target_size = (224, 224, 3))
plt.imshow(pic)
output(img)
# Out:
# 'AMERICAN COOT'

# %%
model.evaluate(test_set)
# Out:
# 45/45 [==============================] - 15s 341ms/step - loss: 2.1200 - accuracy: 0.8526
# [2.119967460632324, 0.8526315689086914]
